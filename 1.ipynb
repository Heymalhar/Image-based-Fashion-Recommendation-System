# %%
from zipfile import ZipFile
import os

# %%
zip_file_path = 'women-fashion.zip'
extraction_directory = 'women_fashion'

if not os.path.exists(extraction_directory):
    os.makedirs(extraction_directory)

with ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_directory)

extracted_files = os.listdir(extraction_directory)
print(extracted_files[:10])
# Out:
# ['women fashion', '__MACOSX']

# %%
# correcting the path to include the 'women fashion' directory and listing its contents
extraction_directory_updated = os.path.join(extraction_directory, 'women fashion')

# list the files in the updated directory
extracted_files_updated = os.listdir(extraction_directory_updated)
extracted_files_updated[:10], len(extracted_files_updated)
# Out:
# (['anarkali suit with a long, olive green kurta adorned with intricate embroidery around the neckline and cuffs, paired with matching fitted trousers.jpg',
#   'Anarkali suit with a modern twist.jpg',
#   'Anarkali suit with fitted bodice with a high neckline.jpg',
#   'anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg',
#   'anarkali suit with lavender in color with intricate white patterns throughout the fabric.jpg',
#   'anarkali suit. It consists of a turquoise skirt with detailed golden embroidery, a multicolored blouse with floral patterns, and an orange dupatta with lace borders.jpg',
#   'ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg',
#   'beige top adorned with black dots and a green skirt.jpg',
#   'black and white gingham checkered A-line dress with a flared skirt.jpg',
#   'black double-breasted blazer with gold buttons, paired with a mid-length skirt.jpg'],
#  96)

# %%
from PIL import Image
import matplotlib.pyplot as plt

def display_image(file_path):
    image = Image.open(file_path)
    plt.imshow(image)
    plt.axis('off')
    plt.show()

first_image_path = os.path.join(extraction_directory_updated, extracted_files_updated[0])
display_image(first_image_path)

# %%
import glob

# directory path containing your images
image_directory = 'women_fashion/women fashion'

image_paths_list = [file for file in glob.glob(os.path.join(image_directory, '*.*')) if file.endswith(('.jpg', '.png', '.jpeg', 'webp'))]

# print the list of image file paths
print(image_paths_list)
# Out:
# ['women_fashion/women fashion\\anarkali suit with a long, olive green kurta adorned with intricate embroidery around the neckline and cuffs, paired with matching fitted trousers.jpg', 'women_fashion/women fashion\\Anarkali suit with a modern twist.jpg', 'women_fashion/women fashion\\Anarkali suit with fitted bodice with a high neckline.jpg', 'women_fashion/women fashion\\anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg', 'women_fashion/women fashion\\anarkali suit with lavender in color with intricate white patterns throughout the fabric.jpg', 'women_fashion/women fashion\\anarkali suit. It consists of a turquoise skirt with detailed golden embroidery, a multicolored blouse with floral patterns, and an orange dupatta with lace borders.jpg', 'women_fashion/women fashion\\ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg', 'women_fashion/women fashion\\beige top adorned with black dots and a green skirt.jpg', 'women_fashion/women fashion\\black and white gingham checkered A-line dress with a flared skirt.jpg', 'women_fashion/women fashion\\black double-breasted blazer with gold buttons, paired with a mid-length skirt.jpg', 'women_fashion/women fashion\\black dress with lace detailing.jpg', 'women_fashion/women fashion\\black dress with sparkling details.jpg', 'women_fashion/women fashion\\black floral saree.jpg', 'women_fashion/women fashion\\black jumpsuit with a diagonal stripe of glittering material running across the body.jpg', 'women_fashion/women fashion\\black lace bustier top paired with high-waisted black trousers.jpg', 'women_fashion/women fashion\\black off-shoulder dress with belt.jpg', 'women_fashion/women fashion\\black top with spaghetti straps and a black skirt adorned with a fringe detail at the hem.jpg', 'women_fashion/women fashion\\black top, white trousers.jpg', 'women_fashion/women fashion\\black, sequined dress with thin shoulder straps.jpg', 'women_fashion/women fashion\\blue dress with a floral pattern.jpg', 'women_fashion/women fashion\\bright red kurta with an intricate patterned design.jpg', 'women_fashion/women fashion\\bright red, form-fitting, strapless dress with a high slit on one side revealing part of the leg.jpg', 'women_fashion/women fashion\\bright red, sequined dress with thin shoulder straps.jpg', 'women_fashion/women fashion\\burgundy off-the-shoulder dress with an asymmetrical hemline.jpg', 'women_fashion/women fashion\\burnt orange long-sleeve top, a plaid skirt with brown tones, and a matching burnt orange beret.jpeg', 'women_fashion/women fashion\\chic and elegant outfit consisting of a pair of high-waisted wide-leg trousers paired with a long-sleeve sheer lace top.jpg', 'women_fashion/women fashion\\classic black slip dress with a midi length.jpg', 'women_fashion/women fashion\\colorful saree.jpg', 'women_fashion/women fashion\\cream-colored, long, open-front coat with wide lapels.jpg', 'women_fashion/women fashion\\dark blue, knee-length dress with thin straps.jpg', 'women_fashion/women fashion\\dark, elegant, sleeveless dress that reaches down to about mid-calf.jpg', 'women_fashion/women fashion\\deep burgundy, silky dress with long sleeves and a wrap-style front.jpg', 'women_fashion/women fashion\\dress with a classic black and white houndstooth pattern.jpg', 'women_fashion/women fashion\\fitted black dress that reaches down to mid-calf.jpg', 'women_fashion/women fashion\\fitted dress with a classic black and white houndstooth pattern.webp', 'women_fashion/women fashion\\fitted, cream-colored dress with long sheer sleeves.jpg', 'women_fashion/women fashion\\fitted, off-the-shoulder white dress with horizontal ribbed texture.jpg', 'women_fashion/women fashion\\fitted, ruched dress with a sweetheart neckline and long mesh sleeves.jpg', 'women_fashion/women fashion\\fitted, short, yellow dress with short sleeves.jpeg', 'women_fashion/women fashion\\floral dress with long sleeves.jpeg', 'women_fashion/women fashion\\flow ...

# %% [markdown]
# --> Model Building and Training

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
import numpy as np

# %%
base_model = VGG16(weights='imagenet', include_top=False)
model = Model(inputs=base_model.input, outputs=base_model.output)

# %%
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded = np.expand_dims(img_array, axis=0)
    return preprocess_input(img_array_expanded)

def extract_features(model, preprocessed_img):
    features = model.predict(preprocessed_img)
    flattened_features = features.flatten()
    normalized_features = flattened_features / np.linalg.norm(flattened_features)
    return normalized_features

all_features = []
all_image_names = []

for img_path in image_paths_list:
    preprocessed_img = preprocess_image(img_path)
    features = extract_features(model, preprocessed_img)
    all_features.append(features)
    all_image_names.append(os.path.basename(img_path))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step

# %%
all_features
# Out:
# [array([0.        , 0.        , 0.        , ..., 0.        , 0.00049293,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00020818,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.00236598, 0.        , ..., 0.        , 0.00562013,
#         0.00019364], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.       , 0.       , 0.       , ..., 0.       , 0.0076243,
#         0.       ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00561854,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00445753,
#         0.        ], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.00159955], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.00124356], dtype=float32),
#  array([0.       , 0.       , 0.       , ..., 0.0114804, 0.       ,
#         0.       ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00103897,
#         0.        ], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00306604,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00027559,
#         0.        ], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00662778,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.       , 0.       , 0.0235182, ..., 0.       , 0.       ,
#         0.       ], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 4.357985e-05, ..., 0.000000e+00,
#         1.974471e-02, 0.000000e+00], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00137756,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00060177,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.00101865, 0.        ,
#         0.00269785], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00154196,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.       , 0.       , 0.       , ..., 0.       , 0.0043248,
#         0.       ], dtype=float32),
#  array([0.       , 0.       , 0.       , ..., 0.       , 0.0084634,
#         0.       ], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.00982463, 0.        ,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00226902,
#         0.        ], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00118044,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.00219198, 0.        , ..., 0.        , 0.01027615,
#         0.        ], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.01410903,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00514907,
#         0.        ], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00165868,
#         0.        ], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.00107348, 0.        ,
#         0.        ], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.00384149, 0.00073029,
#         0.        ], dtype=float32),
#  array([0.        , 0.00472781, 0.        , ..., 0.        , 0.00211758,
#         0.        ], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00417143,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.00703595], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.00179931,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.00365414], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.0016605 , 0.        ,
#         0.00478842], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.02594271, ..., 0.        , 0.0170518 ,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.01288532,
#         0.        ], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , ..., 0.00410492, 0.00142273,
#         0.00026866], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)]

# %%
all_image_names
# Out:
# ['anarkali suit with a long, olive green kurta adorned with intricate embroidery around the neckline and cuffs, paired with matching fitted trousers.jpg',
#  'Anarkali suit with a modern twist.jpg',
#  'Anarkali suit with fitted bodice with a high neckline.jpg',
#  'anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg',
#  'anarkali suit with lavender in color with intricate white patterns throughout the fabric.jpg',
#  'anarkali suit. It consists of a turquoise skirt with detailed golden embroidery, a multicolored blouse with floral patterns, and an orange dupatta with lace borders.jpg',
#  'ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg',
#  'beige top adorned with black dots and a green skirt.jpg',
#  'black and white gingham checkered A-line dress with a flared skirt.jpg',
#  'black double-breasted blazer with gold buttons, paired with a mid-length skirt.jpg',
#  'black dress with lace detailing.jpg',
#  'black dress with sparkling details.jpg',
#  'black floral saree.jpg',
#  'black jumpsuit with a diagonal stripe of glittering material running across the body.jpg',
#  'black lace bustier top paired with high-waisted black trousers.jpg',
#  'black off-shoulder dress with belt.jpg',
#  'black top with spaghetti straps and a black skirt adorned with a fringe detail at the hem.jpg',
#  'black top, white trousers.jpg',
#  'black, sequined dress with thin shoulder straps.jpg',
#  'blue dress with a floral pattern.jpg',
#  'bright red kurta with an intricate patterned design.jpg',
#  'bright red, form-fitting, strapless dress with a high slit on one side revealing part of the leg.jpg',
#  'bright red, sequined dress with thin shoulder straps.jpg',
#  'burgundy off-the-shoulder dress with an asymmetrical hemline.jpg',
#  'burnt orange long-sleeve top, a plaid skirt with brown tones, and a matching burnt orange beret.jpeg',
#  'chic and elegant outfit consisting of a pair of high-waisted wide-leg trousers paired with a long-sleeve sheer lace top.jpg',
#  'classic black slip dress with a midi length.jpg',
#  'colorful saree.jpg',
#  'cream-colored, long, open-front coat with wide lapels.jpg',
#  'dark blue, knee-length dress with thin straps.jpg',
#  'dark, elegant, sleeveless dress that reaches down to about mid-calf.jpg',
#  'deep burgundy, silky dress with long sleeves and a wrap-style front.jpg',
#  'dress with a classic black and white houndstooth pattern.jpg',
#  'fitted black dress that reaches down to mid-calf.jpg',
#  'fitted dress with a classic black and white houndstooth pattern.webp',
#  'fitted, cream-colored dress with long sheer sleeves.jpg',
#  'fitted, off-the-shoulder white dress with horizontal ribbed texture.jpg',
#  'fitted, ruched dress with a sweetheart neckline and long mesh sleeves.jpg',
#  'fitted, short, yellow dress with short sleeves.jpeg',
#  'floral dress with long sleeves.jpeg',
#  'flowing green off-shoulder dress.jpg',
#  'fluffy, possibly faux fur or eyelash knit sweater with a cropped cut top.jpg',
#  'form-fitting dress with a vibrant pattern of yellow, blue, and black.jpg',
#  'glamorous two-piece outfit featuring a sequined design.jpeg',
#  'green dress with a floral pattern, paired with matching green trousers.jpg',
#  'high-waisted white trousers paired with a structured, corset-style bodice featuring mesh.jpg',
#  'l-htdrss7133-honky-tonky-original-imagszfhfghhs2rp.jpeg',
#  'ladies-party-wear-cotton-short-dress-full.jpg',
#  'Latest-Party-Wear-One-Piece-Gown-For-Women.webp',
#  'light blue, sequined dress with a V-neckline, long sleeves.jpg',
#  'light brown sleeveless double-breasted blazer paired with matching straight-leg trousers.jpg',
#  'light green, short dress with lace detailing around the waist and the edges of the sleeves and hem.jpg',
#  'light peach, knee-length dress with off-the-shoulder sleeves.webp',
#  'long, elegant blue dress with an off-the-shoulder design with sheer sleeves.jpg',
#  'long, elegant, teal dress with a high slit on one side.jpg',
#  'long, flowing dress with a full skirt.jpg',
#  'long, flowing, pink dress with a sparkly texture.jpg',
#  'long, intricately designed dress with full sleeves.jpg',
#  'metallic-looking jacket with intricate designs and fringes hanging from the sleeves.jpg',
#  'mustard yellow fitted dress with white off-the-shoulder sleeves.webp',
#  'off-the-shoulder black ball gown.jpg',
#  'one-shoulder, black, sequined dress with fringe detailing at the hem.jpg',
#  'one-shoulder, fitted dress that features sequin embellishments and sheer panels.jpg',
#  'pink, knee-length dress that sparkles.jpg',
#  'red dress adorned with an intricate white pattern.jpg',
#  'red dress with a pattern of small white flowers.jpg',
#  'red velvet sheath midi dress.jpg',
#  'royal blue off-shoulder dress.jpg',
#  'salwar kameez in a vibrant red color with detailed embroidery.jpg',
#  'shiny purple sequined dress with a one-shoulder design.jpg',
#  'shiny, silver, wrap-style dress with long sleeves.jpg',
#  'short, blue floral dress with long puffed sleeves.jpg',
#  'short, white, sleeveless dress with thin straps.jpg',
#  'sleeveless dress adorned with pink sequins.jpg',
#  'sleeveless dress with a high neckline.jpeg',
#  'Sleeveless-Ruched-Tight-Fashion-Sexy-Bodycon-Party-Women-Club-Dresses.webp',
#  'solid dark blue top and a floral pattern on the bottom.jpg',
#  'sophisticated black dress with an asymmetrical design with one sleeve and a strapless neckline on the opposite side.jpg',
#  'sparkling black dress.jpg',
#  'sparkling blue dress.jpeg',
#  'sparkling white dress with long sleeves.jpg',
#  'sparkling, fitted dress 2.jpeg',
#  'sparkling, fitted dress with long sleeves.jpg',
#  'sparkling, fitted dress.jpeg',
#  'sparkling, sequined dress.jpg',
#  'strapless red midi dress with a mermaid silhouette.jpg',
#  'strapless, sequined dress that sparkles with multiple colors.jpg',
#  'tight-fitting, off-the-shoulder white dress 2.jpg',
#  'tight-fitting, off-the-shoulder white dress.webp',
#  'vibrant blue and a neutral tone adorned with colorful floral patterns.jpg',
#  'well-fitted beige suit.jpg',
#  'white dress adorned with colorful floral patterns.jpg',
#  'white knee-length dress with a fitted design and long sleeves.webp',
#  'white, intricately detailed top and a flowing dark blue skirt.jpg',
#  'Women-off-the-shoulder-sexy-embroidery-fashion-party-dress-1.png',
#  'yellow, intricately designed Anarkali suit.jpeg']

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from PIL import Image
from scipy.spatial.distance import cosine

def recommend_fashion_items_cnn(input_image_path, all_features, all_image_names, model, top_n=5):
    # Pre-process the input image and extract features
    preprocessed_img = preprocess_image(input_image_path)
    input_features = extract_features(model, preprocessed_img)

    # Calculate similarities and find the top N similar images
    similarities = [1 - cosine(input_features, other_feature) for other_feature in all_features]
    similar_indices = np.argsort(similarities)[-top_n:]

    # Get the base name of the input image for comparison
    input_image_name = os.path.basename(input_image_path)

    # Filter out the input image index from similar_indices
    similar_indices = [idx for idx in similar_indices if all_image_names[idx] != input_image_name]

    # Display the input image
    plt.figure(figsize=(15, 10))
    plt.subplot(1, top_n + 1, 1)
    plt.imshow(Image.open(input_image_path))
    plt.title("Input Image")
    plt.axis('off')

    # Display similar images
    for i, idx in enumerate(similar_indices[:top_n], start=1):
        image_path = os.path.join('women_fashion/women fashion/', all_image_names[idx])
        plt.subplot(1, top_n + 1, i + 1)
        plt.imshow(Image.open(image_path))
        plt.title(f"Recommendation {i}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the function
input_image_path = 'women_fashion/women fashion/white, intricately detailed top and a flowing dark blue skirt.jpg'
recommend_fashion_items_cnn(input_image_path, all_features, all_image_names, model, top_n=4)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
